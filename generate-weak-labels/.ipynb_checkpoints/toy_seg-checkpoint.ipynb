# %%
from segment_anything import SamAutomaticMaskGenerator, sam_model_registry
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/tanvid/ipykernel_4047356/1893621289.py in <module>
# ----> 1 from segment_anything import SamAutomaticMaskGenerator, sam_model_registry
#
# /deep/u/tanvid/anaconda3/lib/python3.9/site-packages/segment_anything/__init__.py in <module>
#       5 # LICENSE file in the root directory of this source tree.
#       6
# ----> 7 from .build_sam import (
#       8     build_sam,
#       9     build_sam_vit_h,
#
# /deep/u/tanvid/anaconda3/lib/python3.9/site-packages/segment_anything/build_sam.py in <module>
#       5 # LICENSE file in the root directory of this source tree.
#       6
# ----> 7 import torch
#       8
#       9 from functools import partial
#
# ModuleNotFoundError: No module named 'torch'

# %%
sam = sam_model_registry["default"](checkpoint="sam_vit_h_4b8939.pth")
sam.to(device="cuda")
mask_generator = SamAutomaticMaskGenerator(sam)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/tanvid/ipykernel_4047356/1031554468.py in <module>
# ----> 1 sam = sam_model_registry["default"](checkpoint="sam_vit_h_4b8939.pth")
#       2 sam.to(device="cuda")
#       3 mask_generator = SamAutomaticMaskGenerator(sam)
#
# NameError: name 'sam_model_registry' is not defined

# %%
import cv2
image = cv2.imread('Dataset_BUSI_with_GT/malignant/malignant (1).png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)

    img = np.ones((sorted_anns[0]['segmentation'].shape[0], sorted_anns[0]['segmentation'].shape[1], 4))
    img[:,:,3] = 0
    for ann in sorted_anns:
        m = ann['segmentation']
        color_mask = np.concatenate([np.random.random(3), [0.35]])
        img[m] = color_mask
    ax.imshow(img)

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.imshow(image)
plt.axis('off')
plt.savefig("bc.png")
plt.show()

# %%
masks = mask_generator.generate(image)

# %%
print(len(masks))
print(masks[0].keys())
# Out:
# 19
# dict_keys(['segmentation', 'area', 'bbox', 'predicted_iou', 'point_coords', 'stability_score', 'crop_box'])

# %%
import numpy as np
import torch

# %%
plt.figure()
plt.imshow(image)
show_anns(masks)
plt.axis('off')
plt.savefig("seg-bc.png")
plt.show()

# %%
plt.savefig("seg-bc.png")

# %%
image2 = cv2.imread('retina-images/im0112.ppm')
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

# %%
plt.figure()
plt.imshow(image2)
plt.axis('off')
plt.savefig("retina.png")
plt.show()

# %%
masks = mask_generator.generate(image2)

# %%
plt.figure()
plt.imshow(image2)
show_anns(masks)
plt.axis('off')
plt.savefig("seg-retina.png")
plt.show()
